# %%
# %tensorflow_version 1.x # Goole Colab Magic Function
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # Goole Colab Magic Function`. This will be interpreted as: `1.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %%
# %mkdir "Data with pre-processing" # Making Dir. to upload files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Model Training:

# %%
# !python /content/drive/MyDrive/deepsleepnet/train.py --data_dir "/content/drive/MyDrive/sleep-data/" --output_dir output --n_folds 20 --fold_idx 0 --pretrain_epochs 100 --finetune_epochs 200 --resume True
# Out:
# 2021-10-10 03:18:14.294219: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-10-10 03:18:14.316806: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-10 03:18:14.317585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2021-10-10 03:18:14.317932: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-10 03:18:14.320099: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ...

# %% [markdown]
# # Downloading Checkpoint

# %%
# !zip -r "/content/output.zip" "/content/output/"
# Out:
# updating: content/output/ (stored 0%)
#   adding: content/output/fold0/ (stored 0%)
#   adding: content/output/fold0/deepfeaturenet/ (stored 0%)
#   adding: content/output/fold0/deepfeaturenet/deepfeaturenet_l9_conv_conv1d_weights_100.png (deflated 2%)
#   adding: content/output/fold0/deepfeaturenet/params_fold0.npz (deflated 9%)
#   adding: content/output/fold0/deepfeaturenet/deepfeaturenet_l1_conv_conv1d_weights_50.png (deflated 3%)
#   adding: content/output/fold0/deepfeaturenet/deepfeaturenet_l1_conv_conv1d_weights_100.png (deflated 3%)
#   adding: content/output/fold0/deepfeaturenet/model_fold0.ckpt-100.data-00000-of-00001 (deflated 8%)
#   adding: content/output/fold0/deepfeaturenet/model_fold0.ckpt-100.index (deflated 59%)
#   adding: content/output/fold0/deepfeaturenet/checkpoint (deflated 44%)
#   adding: content/output/fold0/deepfeaturenet/deepfeaturenet_l9_conv_conv1d_weights_50.png (deflated 2%)
# ...

# %%
from google.colab import files
files.download("/content/output.zip")

# %%
# !mv /content/output.zip /content/drive/MyDrive

# %% [markdown]
# # PREDICTION

# %%
# !python /content/drive/MyDrive/deepsleepnet/predict.py --data_dir "/content/drive/MyDrive/sleep-data/" --model_dir /content/drive/MyDrive/output --output_dir output
# Out:
# 2021-10-10 05:16:20.468854: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-10-10 05:16:20.496324: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-10 05:16:20.497186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2021-10-10 05:16:20.497509: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-10 05:16:20.499688: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ...
