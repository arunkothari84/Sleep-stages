# %%
# %pip install mne==0.19.0
# Out:
# ...
#   Using cached mne-0.19.0-py3-none-any.whl (6.4 MB)
# ...
#   Attempting uninstall: mne
#     Found existing installation: mne 0.23.4
#     Uninstalling mne-0.23.4:
#       Successfully uninstalled mne-0.23.4Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# !git clone https://github.com/akaraspt/deepsleepnet.git
# Out:
# Cloning into 'deepsleepnet'...

# %%
# !python ./deepsleepnet/prepare_physionet.py --data_dir ./sleep-edf-database-expanded-1.0.0/sleep-cassette/ --output_dir ./data_new/eeg_fpz_cz --select_ch "EEG Fpz-Cz"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\arunk\Downloads\sleep-stage-data\content\deepsleepnet\prepare_physionet.py", line 216, in <module>
#     main()
#   File "C:\Users\arunk\Downloads\sleep-stage-data\content\deepsleepnet\prepare_physionet.py", line 74, in main
#     shutil.rmtree(args.output_dir)
#   File "C:\Users\arunk\anaconda\envs\sleep-stage\lib\shutil.py", line 748, in rmtree
#     return _rmtree_unsafe(path, onerror)
#   File "C:\Users\arunk\anaconda\envs\sleep-stage\lib\shutil.py", line 626, in _rmtree_unsafe
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "C:\Users\arunk\anaconda\envs\sleep-stage\lib\shutil.py", line 624, in _rmtree_unsafe
#     os.unlink(fullname)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: './data_new/eeg_fpz_cz\\SC4021E0.npz'
# ...
